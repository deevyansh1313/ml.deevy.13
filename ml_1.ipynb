# %% [markdown]
# <a href="https://colab.research.google.com/github/deevyansh1313/ml.deevy.13/blob/main/ml_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("python basics")
# Out:
# python basics

# %%
## bassic syntax

# %%
# pythion r case sensitive
name = "deevy"
Name = "rv"
# both names r treated as differnet variables
print(name)
print(Name)
# Out:
# deevy
# rv

# %%
# Indentation is also a must for python
# grouping of statemnts is done through indentation
age = 32
if age > 30:
  print(" u r good to go")
# u can see instead of using curly braces to define a block we use intendation to do this
# Out:
#  u r good to go

# %%
# line continuation
total = 1+2+3+3+3+3+\
3+3 # see this addition is linked to above statement
print(total)
# Out:
# 21

# %%
# understanding semantics in python
age = 32 # no need to do int a # compiler knows in python 32 is int
type(age)
# Out:
# int

# %%
name = "deevyansh"
type(name)
# Out:
# str
